# %%
import pandas as pd
import pytrends
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list =["ESG"]
pytrends.build_payload(kw_list, geo ='GR')

# %%
df=pytrends.interest_over_time()

# %%
df.to_csv("greekGoogleTrendEsg.csv",sep=';')
df.head()
df['ESG'].dtype
# Out:
# dtype('int64')

# %%
ax=df['ESG'].plot(figsize=(18,6),title='Google Trend for ESG in Greece')
ax.set(label='Interest over time')
# Out:
# [None]

# %%
# 12months Simple Moving Average
df['SMA12']=df['ESG'].rolling(window=12).mean()
df[['ESG','SMA12']].plot(figsize=(18,6));
